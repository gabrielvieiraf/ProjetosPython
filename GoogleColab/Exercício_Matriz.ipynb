# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielvieiraf/ProjetosPython/blob/master/GoogleColab/Exerc%C3%ADcio_Matriz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
55
def matriz(m, n):

    print("Digite os elementos da matriz %dx%d:" %(m,n))
    matriz = []
    try:
      for i in range(m):
          matriz.append([])
          for j in range(n):
              elemento = float(input("Elemento M[%d][%d]: " %(i+1,j+1)))
              matriz[i].append(elemento)
    except:

      print('\nAlgum valor foi digitado errado, tente novamente')
      exit()
            
    return matriz

def soma(M):

  print()

  # Imprimindo matriz
  for linha in M:
    for elemento in linha:
      print(elemento, end = " ")
    print()
  
  print()

  soma = float(0)
  i = 0

  while i < 4:
    j=i+1
    while j < 4:
      soma += M[i][j]
      j += 1
    i += 1

  print('A soma dos elementos acima da diagonal da matriz é:  %.2f' % soma)


def media(M):

  print()

  # Imprimindo matriz
  for linha in M:
    for elemento in linha:
      print(elemento, end = " ")
    print()

  soma = float(0)
  i = 0

  while i < 4:
    j=i+1
    while j < 4:
      soma += M[i][j]
      j += 1
    i += 1
  
  media = soma/6

  print('A média dos elementos acima da diagonal da matriz é:  %.2f' % media)
  print()


def menuprinc():
    opcao = input('''
S - Soma
M - Média
Opção:  ''')
    
    if opcao == 'S':
        M = list()
        M = matriz(4,4)
        soma(M)
    elif opcao == 'M':
        M = list()
        M = matriz(4,4)
        media(M)
    else:
        print()
        print("Opção inválida :( \n")
        menuprinc()

while True:
  menuprinc()
# Out:
# S - Soma
# M - Média
# Opção:  M
# Digite os elementos da matriz 4x4:
# Elemento M[1][1]: 5
# Elemento M[1][2]: 5
# Elemento M[1][3]: 5
# Elemento M[1][4]: 5
# Elemento M[2][1]: 5
# Elemento M[2][2]: 5
# Elemento M[2][3]: 5
# Elemento M[2][4]: 5
# Elemento M[3][1]: 5
# Elemento M[3][2]: 5
# Elemento M[3][3]: 5
# Elemento M[3][4]: 5
# Elemento M[4][1]: 5
# Elemento M[4][2]: 5
# Elemento M[4][3]: 5
# Elemento M[4][4]: 5
#
# 5.0 5.0 5.0 5.0
# 5.0 5.0 5.0 5.0
# 5.0 5.0 5.0 5.0
# 5.0 5.0 5.0 5.0
# A média dos elementos acima da diagonal da matriz é:  5.00
#
#
# S - Soma
# M - Média
# Opção:  s
#
# Opção inválida :(
#
#
# S - Soma
# M - Média
# Opção:  S
# Digite os elementos da matriz 4x4:
# Elemento M[1][1]: 5
# Elemento M[1][2]: 5
# Elemento M[1][3]: 5
# Elemento M[1][4]: 5
# Elemento M[2][1]: 5
# Elemento M[2][2]: 5
# Elemento M[2][3]: 5
# Elemento M[2][4]: 5
# Elemento M[3][1]: 5
# Elemento M[3][2]: 5
# Elemento M[3][3]: 5
# Elemento M[3][4]: 5
# Elemento M[4][1]: 5
# ...
